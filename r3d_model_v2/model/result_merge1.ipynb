# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
crash_ego_result = pd.read_csv('/content/drive/MyDrive/result/crash+ego1.csv')
weather_result = pd.read_csv('/content/drive/MyDrive/result/weather1.csv')
timing_result = pd.read_csv('/content/drive/MyDrive/result/timing1.csv')

# %%
result = pd.read_csv('/content/drive/MyDrive/sample_submission.csv')

# %%
for i in range(len(result['label'])):
    if crash_ego_result['label'][i] == 0:
        result['label'][i] = 0
        
    elif crash_ego_result['label'][i] == 1:
        if weather_result['label'][i] == 0:
            if timing_result['label'][i] == 0:
                result['label'][i] = 1
            else:
                result['label'][i] = 2
        elif weather_result['label'][i] == 1:
            if timing_result['label'][i] == 0:
                result['label'][i] = 3
            else:
                result['label'][i] = 4
        else:
            if timing_result['label'][i] == 0:
                result['label'][i] = 5
            else:
                result['label'][i] = 6
                
    else:
        if weather_result['label'][i] == 0:
            if timing_result['label'][i] == 0:
                result['label'][i] = 7
            else:
                result['label'][i] = 8
        elif weather_result['label'][i] == 1:
            if timing_result['label'][i] == 0:
                result['label'][i] = 9
            else:
                result['label'][i] = 10
        else:
            if timing_result['label'][i] == 0:
                result['label'][i] = 11
            else:
                result['label'][i] = 12
# Out:
# <ipython-input-5-d93f80178d15>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['label'][i] = 0
# <ipython-input-5-d93f80178d15>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['label'][i] = 7
# <ipython-input-5-d93f80178d15>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['label'][i] = 9
# <ipython-input-5-d93f80178d15>:35: SettingWithCopyWarning:
# ...

# %%
result.to_csv('/content/drive/MyDrive/result/result1.csv')
