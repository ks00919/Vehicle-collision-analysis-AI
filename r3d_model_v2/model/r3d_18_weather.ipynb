# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 압축풀기
# !unzip /content/drive/MyDrive/lopen.zip
# !mv open data
# Out:
# Archive:  /content/drive/MyDrive/lopen.zip
#   inflating: open/sample_submission.csv
#   inflating: open/test.csv
#    creating: open/test/
#   inflating: open/test/TEST_0000.mp4
#   inflating: open/test/TEST_0001.mp4
#   inflating: open/test/TEST_0002.mp4
#   inflating: open/test/TEST_0003.mp4
#   inflating: open/test/TEST_0004.mp4
#   inflating: open/test/TEST_0005.mp4
#   inflating: open/test/TEST_0006.mp4
#   inflating: open/test/TEST_0007.mp4
#   inflating: open/test/TEST_0008.mp4
#   inflating: open/test/TEST_0009.mp4
#   inflating: open/test/TEST_0010.mp4
#   inflating: open/test/TEST_0011.mp4
#   inflating: open/test/TEST_0012.mp4
#   inflating: open/test/TEST_0013.mp4
#   inflating: open/test/TEST_0014.mp4
#   inflating: open/test/TEST_0015.mp4
#   inflating: open/test/TEST_0016.mp4
#   inflating: open/test/TEST_0017.mp4
#   inflating: open/test/TEST_0018.mp4
#   inflating: open/test/TEST_0019.mp4
#   inflating: open/test/TEST_0020.mp4
#   inflating: open/test/TEST_0021.mp4
#   inflating: open/test/TEST_0022.mp4
#   inflating: open/test/TEST_0023.mp4
#   inflating: open/test/TEST_0024.mp4
#   inflating: open/test/TEST_0025.mp4
#   inflating: open/test/TEST_0026.mp4
#   inflating: open/test/TEST_0027.mp4
#   inflating: open/test/TEST_0028.mp4
#   inflating: open/test/TEST_0029.mp4
#   inflating: open/test/TEST_0030.mp4
#   inflating: open/test/TEST_0031.mp4
#   inflating: open/test/TEST_0032.mp4
#   inflating: open/test/TEST_0033.mp4
#   inflating: open/test/TEST_0034.mp4
#   inflating: open/test/TEST_0035.mp4
#   inflating: open/test/TEST_0036.mp4
#   inflating: open/test/TEST_0037.mp4
#   inflating: open/test/TEST_0038.mp4
#   inflating: open/test/TEST_0039.mp4
#   inflating: open/test/TEST_0040.mp4
#   inflating: open/test/TEST_0041.mp4
#   inflating: open/test/TEST_0042.mp4
#   inflating: open/test/TEST_0043.mp4
#   inflating: open/test/TEST_0044.mp4
#   inflating: open/test/TEST_0045.mp4
#   inflating: open/test/TEST_0046.mp4
#   inflating: open/test/TEST_0047.mp4
#   inflating: open/test/TEST_0048.mp4
#   inflating: open/test/TEST_0049.mp4
#   inflating: open/test/TEST_0050.mp4
#   inflating: open/test/TEST_0051.mp4
#   inflating: open/test/TEST_0052.mp4
#   inflating: open/test/TEST_0053.mp4
#   inflating: open/test/TEST_0054.mp4
#   inflating: open/test/TEST_0055.mp4
#   inflating: open/test/TEST_0056.mp4
#   inflating: open/test/TEST_0057.mp4
#   inflating: open/test/TEST_0058.mp4
#   inflating: open/test/TEST_0059.mp4
#   inflating: open/test/TEST_0060.mp4
#   inflating: open/test/TEST_0061.mp4
#   inflating: open/test/TEST_0062.mp4
#   inflating: open/test/TEST_0063.mp4
#   inflating: open/test/TEST_0064.mp4
#   inflating: open/test/TEST_0065.mp4
#   inflating: open/test/TEST_0066.mp4
#   inflating: open/test/TEST_0140.mp4
#   inflating: open/test/TEST_0141.mp4
#   inflating: open/test/TEST_0142.mp4
#   inflating: open/test/TEST_0143.mp4
#   inflating: open/test/TEST_0144.mp4
#   inflating: open/test/TEST_0145.mp4
#   inflating: open/test/TEST_0146.mp4
#   inflating: open/test/TEST_0147.mp4
#   inflating: open/test/TEST_0148.mp4
#   inflating: open/test/TEST_0149.mp4
#   inflating: open/test/TEST_0150.mp4
#   inflating: open/test/TEST_0151.mp4
#   inflating: open/test/TEST_0152.mp4
#   inflating: open/test/TEST_0153.mp4
#   inflating: open/test/TEST_0154.mp4
#   inflating: open/test/TEST_0155.mp4
#   inflating: open/test/TEST_0156.mp4
#   inflating: open/test/TEST_0157.mp4
#   inflating: open/test/TEST_0158.mp4
#   inflating: open/test/TEST_0159.mp4
#   inflating: open/test/TEST_0160.mp4
#   inflating: open/test/TEST_0161.mp4
#   inflating: open/test/TEST_0162.mp4
#   inflating: open/test/TEST_0163.mp4
#   inflating: open/test/TEST_0164.mp4
#   inflating: open/test/TEST_0165.mp4
#   inflating: open/test/TEST_0166.mp4
#   inflating: open/test/TEST_0167.mp4
#   inflating: open/test/TEST_0168.mp4
#   inflating: open/test/TEST_0169.mp4
#   inflating: open/test/TEST_0170.mp4
#   inflating: open/test/TEST_0171.mp4
#   inflating: open/test/TEST_0172.mp4
#   inflating: open/test/TEST_0173.mp4
#   inflating: open/test/TEST_0174.mp4
#   inflating: open/test/TEST_0175.mp4
#   inflating: open/test/TEST_0176.mp4
#   inflating: open/test/TEST_0177.mp4
#   inflating: open/test/TEST_0178.mp4
#   inflating: open/test/TEST_0179.mp4
#   inflating: open/test/TEST_0180.mp4
#   inflating: open/test/TEST_0181.mp4
#   inflating: open/test/TEST_0182.mp4
#   inflating: open/test/TEST_0183.mp4
#   inflating: open/test/TEST_0184.mp4
#   inflating: open/test/TEST_0185.mp4
#   inflating: open/test/TEST_0186.mp4
#   inflating: open/test/TEST_0187.mp4
#   inflating: open/test/TEST_0188.mp4
#   inflating: open/test/TEST_0189.mp4
#   inflating: open/test/TEST_0190.mp4
#   inflating: open/test/TEST_0191.mp4
#   inflating: open/test/TEST_0192.mp4
#   inflating: open/test/TEST_0193.mp4
#   inflating: open/test/TEST_0194.mp4
#   inflating: open/test/TEST_0195.mp4
#   inflating: open/test/TEST_0196.mp4
#   inflating: open/test/TEST_0197.mp4
#   inflating: open/test/TEST_0198.mp4
#   inflating: open/test/TEST_0199.mp4
#   inflating: open/test/TEST_0200.mp4
#   inflating: open/test/TEST_0201.mp4
#   inflating: open/test/TEST_0202.mp4
#   inflating: open/test/TEST_0203.mp4
#   inflating: open/test/TEST_0204.mp4
#   inflating: open/test/TEST_0205.mp4
#   inflating: open/test/TEST_0206.mp4
#   inflating: open/test/TEST_0207.mp4
#   inflating: open/test/TEST_0208.mp4
#   inflating: open/test/TEST_0209.mp4
#   inflating: open/test/TEST_0210.mp4
#   inflating: open/test/TEST_0211.mp4
#   inflating: open/test/TEST_0212.mp4
#   inflating: open/test/TEST_0868.mp4
#   inflating: open/test/TEST_0869.mp4
#   inflating: open/test/TEST_0870.mp4
#   inflating: open/test/TEST_0871.mp4
#   inflating: open/test/TEST_0872.mp4
#   inflating: open/test/TEST_0873.mp4
#   inflating: open/test/TEST_0874.mp4
#   inflating: open/test/TEST_0875.mp4
#   inflating: open/test/TEST_0876.mp4
#   inflating: open/test/TEST_0877.mp4
#   inflating: open/test/TEST_0878.mp4
#   inflating: open/test/TEST_0879.mp4
#   inflating: open/test/TEST_0880.mp4
#   inflating: open/test/TEST_0881.mp4
#   inflating: open/test/TEST_0882.mp4
#   inflating: open/test/TEST_0883.mp4
#   inflating: open/test/TEST_0884.mp4
#   inflating: open/test/TEST_0885.mp4
#   inflating: open/test/TEST_0886.mp4
#   inflating: open/test/TEST_0887.mp4
#   inflating: open/test/TEST_0888.mp4
#   inflating: open/test/TEST_0889.mp4
#   inflating: open/test/TEST_0890.mp4
#   inflating: open/test/TEST_0891.mp4
#   inflating: open/test/TEST_0892.mp4
#   inflating: open/test/TEST_0893.mp4
#   inflating: open/test/TEST_0894.mp4
#   inflating: open/test/TEST_0895.mp4
#   inflating: open/test/TEST_0896.mp4
#   inflating: open/test/TEST_0897.mp4
#   inflating: open/test/TEST_0898.mp4
#   inflating: open/test/TEST_0899.mp4
#   inflating: open/test/TEST_0900.mp4
#   inflating: open/test/TEST_0901.mp4
#   inflating: open/test/TEST_0902.mp4
#   inflating: open/test/TEST_0903.mp4
#   inflating: open/test/TEST_0904.mp4
#   inflating: open/test/TEST_0905.mp4
#   inflating: open/test/TEST_0906.mp4
#   inflating: open/test/TEST_0907.mp4
#   inflating: open/test/TEST_0908.mp4
#   inflating: open/test/TEST_0909.mp4
#   inflating: open/test/TEST_0910.mp4
#   inflating: open/test/TEST_0911.mp4
#   inflating: open/test/TEST_0912.mp4
#   inflating: open/test/TEST_0913.mp4
#   inflating: open/test/TEST_0914.mp4
#   inflating: open/test/TEST_0915.mp4
#   inflating: open/test/TEST_0916.mp4
#   inflating: open/test/TEST_0917.mp4
#   inflating: open/test/TEST_0918.mp4
#   inflating: open/test/TEST_0919.mp4
#   inflating: open/test/TEST_0920.mp4
#   inflating: open/test/TEST_0921.mp4
#   inflating: open/test/TEST_0922.mp4
#   inflating: open/test/TEST_0923.mp4
#   inflating: open/test/TEST_0924.mp4
#   inflating: open/test/TEST_0925.mp4
#   inflating: open/test/TEST_0926.mp4
#   inflating: open/test/TEST_0927.mp4
#   inflating: open/test/TEST_0928.mp4
#   inflating: open/test/TEST_0929.mp4
#   inflating: open/test/TEST_0930.mp4
#   inflating: open/test/TEST_0931.mp4
#   inflating: open/test/TEST_0932.mp4
#   inflating: open/test/TEST_0933.mp4
#   inflating: open/test/TEST_0934.mp4
#   inflating: open/test/TEST_0935.mp4
#   inflating: open/test/TEST_0936.mp4
#   inflating: open/test/TEST_0937.mp4
#   inflating: open/test/TEST_0938.mp4
#   inflating: open/test/TEST_0939.mp4
#   inflating: open/test/TEST_0940.mp4
#   inflating: open/train/TRAIN_2312.mp4
#   inflating: open/train/TRAIN_2313.mp4
#   inflating: open/train/TRAIN_2314.mp4
#   inflating: open/train/TRAIN_2315.mp4
#   inflating: open/train/TRAIN_2316.mp4
#   inflating: open/train/TRAIN_2317.mp4
#   inflating: open/train/TRAIN_2318.mp4
#   inflating: open/train/TRAIN_2319.mp4
#   inflating: open/train/TRAIN_2320.mp4
#   inflating: open/train/TRAIN_2321.mp4
#   inflating: open/train/TRAIN_2322.mp4
#   inflating: open/train/TRAIN_2323.mp4
#   inflating: open/train/TRAIN_2324.mp4
#   inflating: open/train/TRAIN_2325.mp4
#   inflating: open/train/TRAIN_2326.mp4
#   inflating: open/train/TRAIN_2327.mp4
#   inflating: open/train/TRAIN_2328.mp4
#   inflating: open/train/TRAIN_2329.mp4
#   inflating: open/train/TRAIN_2330.mp4
#   inflating: open/train/TRAIN_2331.mp4
#   inflating: open/train/TRAIN_2332.mp4
#   inflating: open/train/TRAIN_2333.mp4
#   inflating: open/train/TRAIN_2334.mp4
#   inflating: open/train/TRAIN_2335.mp4
#   inflating: open/train/TRAIN_2336.mp4
#   inflating: open/train/TRAIN_2337.mp4
#   inflating: open/train/TRAIN_2338.mp4
#   inflating: open/train/TRAIN_2339.mp4
#   inflating: open/train/TRAIN_2340.mp4
#   inflating: open/train/TRAIN_2341.mp4
#   inflating: open/train/TRAIN_2342.mp4
#   inflating: open/train/TRAIN_2343.mp4
#   inflating: open/train/TRAIN_2344.mp4
#   inflating: open/train/TRAIN_2345.mp4
#   inflating: open/train/TRAIN_2346.mp4
#   inflating: open/train/TRAIN_2347.mp4
#   inflating: open/train/TRAIN_2348.mp4
#   inflating: open/train/TRAIN_2349.mp4
#   inflating: open/train/TRAIN_2350.mp4
#   inflating: open/train/TRAIN_2351.mp4
#   inflating: open/train/TRAIN_2352.mp4
#   inflating: open/train/TRAIN_2353.mp4
#   inflating: open/train/TRAIN_2354.mp4
#   inflating: open/train/TRAIN_2355.mp4
#   inflating: open/train/TRAIN_2356.mp4
#   inflating: open/train/TRAIN_2357.mp4
#   inflating: open/train/TRAIN_2358.mp4
#   inflating: open/train/TRAIN_2359.mp4
#   inflating: open/train/TRAIN_2360.mp4
#   inflating: open/train/TRAIN_2361.mp4
#   inflating: open/train/TRAIN_2362.mp4
#   inflating: open/train/TRAIN_2363.mp4
#   inflating: open/train/TRAIN_2364.mp4
#   inflating: open/train/TRAIN_2365.mp4
#   inflating: open/train/TRAIN_2366.mp4
#   inflating: open/train/TRAIN_2367.mp4
#   inflating: open/train/TRAIN_2368.mp4
#   inflating: open/train/TRAIN_2369.mp4
#   inflating: open/train/TRAIN_2370.mp4
#   inflating: open/train/TRAIN_2371.mp4
#   inflating: open/train/TRAIN_2372.mp4
#   inflating: open/train/TRAIN_2373.mp4
#   inflating: open/train/TRAIN_2374.mp4
#   inflating: open/train/TRAIN_2375.mp4
#   inflating: open/train/TRAIN_2376.mp4
#   inflating: open/train/TRAIN_2377.mp4
#   inflating: open/train/TRAIN_2378.mp4
#   inflating: open/train/TRAIN_2379.mp4
#   inflating: open/train/TRAIN_2380.mp4
#   inflating: open/train/TRAIN_2381.mp4
#   inflating: open/train/TRAIN_2382.mp4
#   inflating: open/train/TRAIN_2383.mp4
#   inflating: open/train/TRAIN_2384.mp4
#   inflating: open/train/TRAIN_2385.mp4
#   inflating: open/train/TRAIN_2386.mp4
#   inflating: open/train/TRAIN_2387.mp4
#   inflating: open/train/TRAIN_2388.mp4
#   inflating: open/train/TRAIN_2389.mp4
#   inflating: open/train/TRAIN_2390.mp4
#   inflating: open/train/TRAIN_2391.mp4
#   inflating: open/train/TRAIN_2392.mp4
#   inflating: open/train/TRAIN_2393.mp4
#   inflating: open/train/TRAIN_2394.mp4
#   inflating: open/train/TRAIN_2395.mp4
#   inflating: open/train/TRAIN_2396.mp4
#   inflating: open/train/TRAIN_2397.mp4
#   inflating: open/train/TRAIN_2398.mp4
#   inflating: open/train/TRAIN_2399.mp4
#   inflating: open/train/TRAIN_2400.mp4
#   inflating: open/train/TRAIN_2401.mp4
#   inflating: open/train/TRAIN_2402.mp4
#   inflating: open/train/TRAIN_2403.mp4
#   inflating: open/train/TRAIN_2404.mp4
#   inflating: open/train/TRAIN_2405.mp4
#   inflating: open/train/TRAIN_2406.mp4
#   inflating: open/train/TRAIN_2407.mp4
#   inflating: open/train/TRAIN_2408.mp4
#   inflating: open/train/TRAIN_2409.mp4
#   inflating: open/train/TRAIN_2410.mp4
#   inflating: open/train/TRAIN_2411.mp4
#   inflating: open/train/TRAIN_2412.mp4
#   inflating: open/train/TRAIN_2413.mp4
#   inflating: open/train/TRAIN_2414.mp4
#   inflating: open/train/TRAIN_2415.mp4
#   inflating: open/train/TRAIN_2416.mp4
#   inflating: open/train/TRAIN_2417.mp4
#   inflating: open/train/TRAIN_2418.mp4
#   inflating: open/train/TRAIN_2419.mp4
#   inflating: open/train/TRAIN_2420.mp4
#   inflating: open/train/TRAIN_2421.mp4
#   inflating: open/train/TRAIN_2422.mp4
#   inflating: open/train/TRAIN_2423.mp4
#   inflating: open/train/TRAIN_2424.mp4
#   inflating: open/train/TRAIN_2425.mp4
#   inflating: open/train/TRAIN_2426.mp4
#   inflating: open/train/TRAIN_2427.mp4
#   inflating: open/train/TRAIN_2428.mp4
#   inflating: open/train/TRAIN_2429.mp4
#   inflating: open/train/TRAIN_2430.mp4
#   inflating: open/train/TRAIN_2431.mp4
#   inflating: open/train/TRAIN_2432.mp4
#   inflating: open/train/TRAIN_2433.mp4
#   inflating: open/train/TRAIN_2434.mp4
#   inflating: open/train/TRAIN_2435.mp4
#   inflating: open/train/TRAIN_2436.mp4
#   inflating: open/train/TRAIN_2437.mp4
#   inflating: open/train/TRAIN_2438.mp4
#   inflating: open/train/TRAIN_2439.mp4
#   inflating: open/train/TRAIN_2440.mp4
#   inflating: open/train/TRAIN_2441.mp4
#   inflating: open/train/TRAIN_2442.mp4
#   inflating: open/train/TRAIN_2443.mp4
#   inflating: open/train/TRAIN_2444.mp4
#   inflating: open/train/TRAIN_2445.mp4
#   inflating: open/train/TRAIN_2446.mp4
#   inflating: open/train/TRAIN_2447.mp4
#   inflating: open/train/TRAIN_2448.mp4
#   inflating: open/train/TRAIN_2449.mp4
#   inflating: open/train/TRAIN_2450.mp4
#   inflating: open/train/TRAIN_2451.mp4
#   inflating: open/train/TRAIN_2452.mp4
#   inflating: open/train/TRAIN_2453.mp4
#   inflating: open/train/TRAIN_2454.mp4
#   inflating: open/train/TRAIN_2455.mp4
#   inflating: open/train/TRAIN_2456.mp4
#   inflating: open/train/TRAIN_2457.mp4
#   inflating: open/train/TRAIN_2458.mp4
#   inflating: open/train/TRAIN_2459.mp4
#   inflating: open/train/TRAIN_2460.mp4
#   inflating: open/train/TRAIN_2461.mp4
#   inflating: open/train/TRAIN_2462.mp4
#   inflating: open/train/TRAIN_2463.mp4
#   inflating: open/train/TRAIN_2464.mp4
#   inflating: open/train/TRAIN_2465.mp4
#   inflating: open/train/TRAIN_2466.mp4
#   inflating: open/train/TRAIN_2467.mp4
#   inflating: open/train/TRAIN_2468.mp4
#   inflating: open/train/TRAIN_2469.mp4
#   inflating: open/train/TRAIN_2470.mp4
#   inflating: open/train/TRAIN_2471.mp4
#   inflating: open/train/TRAIN_2472.mp4
#   inflating: open/train/TRAIN_2473.mp4
#   inflating: open/train/TRAIN_2474.mp4
#   inflating: open/train/TRAIN_2475.mp4
#   inflating: open/train/TRAIN_2476.mp4
#   inflating: open/train/TRAIN_2477.mp4
#   inflating: open/train/TRAIN_2478.mp4
#   inflating: open/train/TRAIN_2479.mp4
#   inflating: open/train/TRAIN_2480.mp4
#   inflating: open/train/TRAIN_2481.mp4
#   inflating: open/train/TRAIN_2482.mp4
#   inflating: open/train/TRAIN_2483.mp4
#   inflating: open/train/TRAIN_2484.mp4
#   inflating: open/train/TRAIN_2485.mp4
#   inflating: open/train/TRAIN_2486.mp4
#   inflating: open/train/TRAIN_2487.mp4
#   inflating: open/train/TRAIN_2488.mp4
#   inflating: open/train/TRAIN_2489.mp4
#   inflating: open/train/TRAIN_2490.mp4
#   inflating: open/train/TRAIN_2491.mp4
#   inflating: open/train/TRAIN_2492.mp4
#   inflating: open/train/TRAIN_2493.mp4
#   inflating: open/train/TRAIN_2494.mp4
#   inflating: open/train/TRAIN_2495.mp4
#   inflating: open/train/TRAIN_2496.mp4
#   inflating: open/train/TRAIN_2497.mp4
#   inflating: open/train/TRAIN_2498.mp4
#   inflating: open/train/TRAIN_2499.mp4
#   inflating: open/train/TRAIN_2500.mp4
#   inflating: open/train/TRAIN_2501.mp4
#   inflating: open/train/TRAIN_2502.mp4
#   inflating: open/train/TRAIN_2503.mp4
#   inflating: open/train/TRAIN_2504.mp4
#   inflating: open/train/TRAIN_2505.mp4
#   inflating: open/train/TRAIN_2506.mp4
#   inflating: open/train/TRAIN_2507.mp4
#   inflating: open/train/TRAIN_2508.mp4
#   inflating: open/train/TRAIN_2509.mp4
#   inflating: open/train/TRAIN_2510.mp4
#   inflating: open/train/TRAIN_2511.mp4
#   inflating: open/train/TRAIN_2512.mp4
#   inflating: open/train/TRAIN_2513.mp4
#   inflating: open/train/TRAIN_2514.mp4
#   inflating: open/train/TRAIN_2515.mp4
#   inflating: open/train/TRAIN_2516.mp4
#   inflating: open/train/TRAIN_2517.mp4
#   inflating: open/train/TRAIN_2518.mp4
#   inflating: open/train/TRAIN_2519.mp4
#   inflating: open/train/TRAIN_2520.mp4
#   inflating: open/train/TRAIN_2521.mp4
#   inflating: open/train/TRAIN_2522.mp4
#   inflating: open/train/TRAIN_2523.mp4
#   inflating: open/train/TRAIN_2524.mp4
#   inflating: open/train/TRAIN_2525.mp4
#   inflating: open/train/TRAIN_2526.mp4
#   inflating: open/train/TRAIN_2527.mp4
#   inflating: open/train/TRAIN_2528.mp4
#   inflating: open/train/TRAIN_2529.mp4
#   inflating: open/train/TRAIN_2530.mp4
#   inflating: open/train/TRAIN_2531.mp4
#   inflating: open/train/TRAIN_2532.mp4
#   inflating: open/train/TRAIN_2533.mp4
#   inflating: open/train/TRAIN_2534.mp4
#   inflating: open/train/TRAIN_2535.mp4
#   inflating: open/train/TRAIN_2536.mp4
#   inflating: open/train/TRAIN_2537.mp4
#   inflating: open/train/TRAIN_2538.mp4
#   inflating: open/train/TRAIN_2539.mp4
#   inflating: open/train/TRAIN_2540.mp4
#   inflating: open/train/TRAIN_2541.mp4
#   inflating: open/train/TRAIN_2542.mp4
#   inflating: open/train/TRAIN_2543.mp4
#   inflating: open/train/TRAIN_2544.mp4
#   inflating: open/train/TRAIN_2545.mp4
#   inflating: open/train/TRAIN_2546.mp4
#   inflating: open/train/TRAIN_2547.mp4
#   inflating: open/train/TRAIN_2548.mp4
#   inflating: open/train/TRAIN_2549.mp4
#   inflating: open/train/TRAIN_2550.mp4
#   inflating: open/train/TRAIN_2551.mp4
#   inflating: open/train/TRAIN_2552.mp4
#   inflating: open/train/TRAIN_2553.mp4
#   inflating: open/train/TRAIN_2554.mp4
#   inflating: open/train/TRAIN_2555.mp4
#   inflating: open/train/TRAIN_2556.mp4
#   inflating: open/train/TRAIN_2557.mp4
#   inflating: open/train/TRAIN_2558.mp4
#   inflating: open/train/TRAIN_2559.mp4
#   inflating: open/train/TRAIN_2560.mp4
#   inflating: open/train/TRAIN_2561.mp4
#   inflating: open/train/TRAIN_2562.mp4
#   inflating: open/train/TRAIN_2563.mp4
#   inflating: open/train/TRAIN_2564.mp4
#   inflating: open/train/TRAIN_2565.mp4
#   inflating: open/train/TRAIN_2566.mp4
#   inflating: open/train/TRAIN_2567.mp4
#   inflating: open/train/TRAIN_2568.mp4
#   inflating: open/train/TRAIN_2569.mp4
#   inflating: open/train/TRAIN_2570.mp4
#   inflating: open/train/TRAIN_2571.mp4
#   inflating: open/train/TRAIN_2572.mp4
#   inflating: open/train/TRAIN_2573.mp4
#   inflating: open/train/TRAIN_2574.mp4
#   inflating: open/train/TRAIN_2575.mp4
#   inflating: open/train/TRAIN_2576.mp4
#   inflating: open/train/TRAIN_2577.mp4
#   inflating: open/train/TRAIN_2578.mp4
#   inflating: open/train/TRAIN_2579.mp4
#   inflating: open/train/TRAIN_2580.mp4
#   inflating: open/train/TRAIN_2581.mp4
#   inflating: open/train/TRAIN_2582.mp4
#   inflating: open/train/TRAIN_2583.mp4
#   inflating: open/train/TRAIN_2584.mp4
#   inflating: open/train/TRAIN_2585.mp4
#   inflating: open/train/TRAIN_2586.mp4
#   inflating: open/train/TRAIN_2587.mp4
#   inflating: open/train/TRAIN_2588.mp4
#   inflating: open/train/TRAIN_2589.mp4
#   inflating: open/train/TRAIN_2590.mp4
#   inflating: open/train/TRAIN_2591.mp4
#   inflating: open/train/TRAIN_2592.mp4
#   inflating: open/train/TRAIN_2593.mp4
#   inflating: open/train/TRAIN_2594.mp4
#   inflating: open/train/TRAIN_2595.mp4
#   inflating: open/train/TRAIN_2596.mp4
#   inflating: open/train/TRAIN_2597.mp4
#   inflating: open/train/TRAIN_2598.mp4
#   inflating: open/train/TRAIN_2599.mp4
#   inflating: open/train/TRAIN_2600.mp4
#   inflating: open/train/TRAIN_2601.mp4
#   inflating: open/train/TRAIN_2602.mp4
#   inflating: open/train/TRAIN_2603.mp4
#   inflating: open/train/TRAIN_2604.mp4
#   inflating: open/train/TRAIN_2605.mp4
#   inflating: open/train/TRAIN_2606.mp4
#   inflating: open/train/TRAIN_2607.mp4
#   inflating: open/train/TRAIN_2608.mp4
#   inflating: open/train/TRAIN_2609.mp4
#   inflating: open/train/TRAIN_2610.mp4
#   inflating: open/train/TRAIN_2611.mp4
#   inflating: open/train/TRAIN_2612.mp4
#   inflating: open/train/TRAIN_2613.mp4
#   inflating: open/train/TRAIN_2614.mp4
#   inflating: open/train/TRAIN_2615.mp4
#   inflating: open/train/TRAIN_2616.mp4
#   inflating: open/train/TRAIN_2617.mp4
#   inflating: open/train/TRAIN_2618.mp4
#   inflating: open/train/TRAIN_2619.mp4
#   inflating: open/train/TRAIN_2620.mp4
#   inflating: open/train/TRAIN_2621.mp4
#   inflating: open/train/TRAIN_2622.mp4
#   inflating: open/train/TRAIN_2623.mp4
#   inflating: open/train/TRAIN_2624.mp4
#   inflating: open/train/TRAIN_2625.mp4
#   inflating: open/train/TRAIN_2626.mp4
#   inflating: open/train/TRAIN_2627.mp4
#   inflating: open/train/TRAIN_2628.mp4
#   inflating: open/train/TRAIN_2629.mp4
#   inflating: open/train/TRAIN_2630.mp4
#   inflating: open/train/TRAIN_2631.mp4
#   inflating: open/train/TRAIN_2632.mp4
#   inflating: open/train/TRAIN_2633.mp4
#   inflating: open/train/TRAIN_2634.mp4
#   inflating: open/train/TRAIN_2635.mp4
#   inflating: open/train/TRAIN_2636.mp4
#   inflating: open/train/TRAIN_2637.mp4
#   inflating: open/train/TRAIN_2638.mp4
#   inflating: open/train/TRAIN_2639.mp4
#   inflating: open/train/TRAIN_2640.mp4
#   inflating: open/train/TRAIN_2641.mp4
#   inflating: open/train/TRAIN_2642.mp4
#   inflating: open/train/TRAIN_2643.mp4
#   inflating: open/train/TRAIN_2644.mp4
#   inflating: open/train/TRAIN_2645.mp4
#   inflating: open/train/TRAIN_2646.mp4
#   inflating: open/train/TRAIN_2647.mp4
#   inflating: open/train/TRAIN_2648.mp4
#   inflating: open/train/TRAIN_2649.mp4
#   inflating: open/train/TRAIN_2650.mp4
#   inflating: open/train/TRAIN_2651.mp4
#   inflating: open/train/TRAIN_2652.mp4
#   inflating: open/train/TRAIN_2653.mp4
#   inflating: open/train/TRAIN_2654.mp4
#   inflating: open/train/TRAIN_2655.mp4
#   inflating: open/train/TRAIN_2656.mp4
#   inflating: open/train/TRAIN_2657.mp4
#   inflating: open/train/TRAIN_2658.mp4
#   inflating: open/train/TRAIN_2659.mp4
#   inflating: open/train/TRAIN_2660.mp4
#   inflating: open/train/TRAIN_2661.mp4
#   inflating: open/train/TRAIN_2662.mp4
#   inflating: open/train/TRAIN_2663.mp4
#   inflating: open/train/TRAIN_2664.mp4
#   inflating: open/train/TRAIN_2665.mp4
#   inflating: open/train/TRAIN_2666.mp4
#   inflating: open/train/TRAIN_2667.mp4
#   inflating: open/train/TRAIN_2668.mp4
#   inflating: open/train/TRAIN_2669.mp4
#   inflating: open/train/TRAIN_2670.mp4
#   inflating: open/train/TRAIN_2671.mp4
#   inflating: open/train/TRAIN_2672.mp4
#   inflating: open/train/TRAIN_2673.mp4
#   inflating: open/train/TRAIN_2674.mp4
#   inflating: open/train/TRAIN_2675.mp4
#   inflating: open/train/TRAIN_2676.mp4
#   inflating: open/train/TRAIN_2677.mp4
#   inflating: open/train/TRAIN_2679.mp4
#   inflating: open/train/TRAIN_2680.mp4
#   inflating: open/train/TRAIN_2681.mp4
#   inflating: open/train/TRAIN_2682.mp4
#   inflating: open/train/TRAIN_2683.mp4
#   inflating: open/train/TRAIN_2684.mp4
#   inflating: open/train/TRAIN_2685.mp4
#   inflating: open/train/TRAIN_2686.mp4
#   inflating: open/train/TRAIN_2687.mp4
#   inflating: open/train/TRAIN_2688.mp4
#   inflating: open/train/TRAIN_2689.mp4
#   inflating: open/train/TRAIN_2690.mp4
#   inflating: open/train/TRAIN_2691.mp4
#   inflating: open/train/TRAIN_2692.mp4
#   inflating: open/train/TRAIN_2693.mp4
#   inflating: open/train/TRAIN_2694.mp4
#   inflating: open/train/TRAIN_2695.mp4
#   inflating: open/train/TRAIN_2696.mp4
#   inflating: open/train/TRAIN_2697.mp4

# %%
import random
import pandas as pd
import numpy as np
import os
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import torchvision.models as models

from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

import warnings
warnings.filterwarnings(action='ignore')

# %%
from PIL import Image
from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# Hyperparameter Setting
CFG = {
    'VIDEO_LENGTH':50, # 10프레임 * 5초
    'IMG_SIZE':128,
    'EPOCHS':10,
    'LEARNING_RATE':3e-4,
    'BATCH_SIZE':4,
    'SEED':41
}

# %%
# Fixed RandomSeed
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %%
# 0 : Non-Crash 1 : Ego-Involve Yes 2 : Ego-Involve No
def crash_transform(label):
  if label == 0 :
    label = 0
  elif label > 7:
    label = 1
  else:
    label = 2
  return label

# 0 : Normal 1 : Snowy 2 : Rainy
def weather_transform(label):
  if label in [1,2,7,8]:
    label = 0
  elif label in [3,4,9,10]:
    label = 1
  elif label in [5,6,11,12]:
    label = 2
  return label

# %%
# Data Load
df = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
# train set의 video_path 수정
df['video_path'] = df['video_path'].apply(lambda x: os.path.join('./data', x[2:]))
df['video_path'].head()
# Out:
# 0    ./data/train/TRAIN_0000.mp4
# 1    ./data/train/TRAIN_0001.mp4
# 2    ./data/train/TRAIN_0002.mp4
# 3    ./data/train/TRAIN_0003.mp4
# 4    ./data/train/TRAIN_0004.mp4
# Name: video_path, dtype: object

# %%
# test set의 video_path 수정
test['video_path'] = test['video_path'].apply(lambda x: os.path.join('./data', x[2:]))
test['video_path'].head()
# Out:
# 0    ./data/test/TEST_0000.mp4
# 1    ./data/test/TEST_0001.mp4
# 2    ./data/test/TEST_0002.mp4
# 3    ./data/test/TEST_0003.mp4
# 4    ./data/test/TEST_0004.mp4
# Name: video_path, dtype: object

# %%
# 0 : Non-Crash 1 : Ego-Involve Yes 2 : Ego-Involve No
crash_ego_df = df.copy()
crash_ego_df['label'] = crash_ego_df['label'].apply(lambda label : crash_transform(label))

# Non-crash 데이터 제외
# 0 : day 1 : night
timing_df = df.loc[df['label']!=0]
timing_df['label'] = timing_df['label'].apply(lambda label : 0 if label in [1, 3, 5, 7, 9, 11] else 1)

# Non-crash 데이터 제외
# 0 : Normal 1 : Snowy 2 : Rainy
weather_df = df.loc[df['label']!=0]
weather_df['label'] = weather_df['label'].apply(lambda label : weather_transform(label))

# %%
# Train / Validation Split
crash_ego_train_set, crash_ego_val_set, _, _ = train_test_split(crash_ego_df,
                                                                crash_ego_df['label'],
                                                                test_size=0.1,
                                                                random_state=CFG['SEED'])

timing_train_set, timing_val_set, _, _ = train_test_split(timing_df,
                                                          timing_df['label'],
                                                          test_size=0.2,
                                                          random_state=CFG['SEED'])

weather_train_set, weather_val_set, _, _ = train_test_split(weather_df,
                                                            weather_df['label'],
                                                            test_size=0.2,
                                                            random_state=CFG['SEED'])

# %%
print('Crash+ego_involve\n', crash_ego_train_set['label'].value_counts(), '\n', crash_ego_val_set['label'].value_counts())
print('Train 데이터 비율:', crash_ego_train_set['label'].value_counts().sum()/(crash_ego_train_set['label'].value_counts().sum()+crash_ego_val_set['label'].value_counts().sum()))
print('Val 데이터 비율:', crash_ego_val_set['label'].value_counts().sum()/(crash_ego_train_set['label'].value_counts().sum()+crash_ego_val_set['label'].value_counts().sum()),'\n')

print('Weather\n', weather_train_set['label'].value_counts(), '\n', weather_val_set['label'].value_counts())
print('Train 데이터 비율:', weather_train_set['label'].value_counts().sum()/(weather_train_set['label'].value_counts().sum()+weather_val_set['label'].value_counts().sum()))
print('Val 데이터 비율:', weather_val_set['label'].value_counts().sum()/(weather_train_set['label'].value_counts().sum()+weather_val_set['label'].value_counts().sum()),'\n')

print('Timing\n', timing_train_set['label'].value_counts(), '\n', timing_val_set['label'].value_counts())
print('Train 데이터 비율:', timing_train_set['label'].value_counts().sum()/(timing_train_set['label'].value_counts().sum()+timing_val_set['label'].value_counts().sum()))
print('Val 데이터 비율:', timing_val_set['label'].value_counts().sum()/(timing_train_set['label'].value_counts().sum()+timing_val_set['label'].value_counts().sum()))
# Out:
# Crash+ego_involve
#  0    1603
# 2     695
# 1     115
# Name: label, dtype: int64
#  0    190
# 2     69
# 1     10
# Name: label, dtype: int64
# Train 데이터 비율: 0.8997017151379567
# Val 데이터 비율: 0.10029828486204326
#
# Weather
#  0    488
# 1    157
# 2     66
# Name: label, dtype: int64
#  0    128
# 1     31
# 2     19
# Name: label, dtype: int64
# Train 데이터 비율: 0.7997750281214848
# Val 데이터 비율: 0.20022497187851518
#
# Timing
#  0    627
# 1     84
# Name: label, dtype: int64
#  0    161
# 1     17
# Name: label, dtype: int64
# Train 데이터 비율: 0.7997750281214848
# Val 데이터 비율: 0.20022497187851518

# %%
#CustomDataset

def cv2_to_pil(image):
    return Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

class CustomDataset1(Dataset):
    def __init__(self, video_path_list, label_list, tfms):
        self.video_path_list = video_path_list
        self.label_list = label_list
        self.tfms = tfms
        
    def __getitem__(self, index):
        frames = self.get_video(self.video_path_list[index])
        
        if self.label_list is not None:
            label = self.label_list[index]
            return frames, label
        else:
            return frames
        
    def __len__(self):
        return len(self.video_path_list)
    
    def get_video(self, path):
        frames = []
        cap = cv2.VideoCapture(path)
        for _ in range(CFG['VIDEO_LENGTH']):
            _, img = cap.read()
            img = cv2.resize(img,(CFG["IMG_SIZE"], CFG["IMG_SIZE"]), interpolation = cv2.INTER_AREA)
            img = cv2_to_pil(img)
            img = (self.tfms(img))
            frames.append(img)
        frames = torch.from_numpy(np.stack(frames))
        return torch.FloatTensor(np.array(frames)).permute(1,0,2,3)

train_transform = Compose([
                 ToTensor(), 
                 Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989])])

# %%
class CustomDataset2(Dataset):
    def __init__(self, video_path_list, label_list, tfms):
        self.video_path_list = video_path_list
        self.label_list = label_list
        self.tfms = tfms
        
    def __getitem__(self, index):
        frames = self.get_video(self.video_path_list[index])
        
        if self.label_list is not None:
            label = self.label_list[index]
            return frames, label
        else:
            return frames
        
    def __len__(self):
        return len(self.video_path_list)
    
    def get_video(self, path):
        frames = []
        cap = cv2.VideoCapture(path)
        for _ in range(CFG['VIDEO_LENGTH']):
            _, img = cap.read()
            img = cv2.resize(img,(200, 200), interpolation = cv2.INTER_AREA)
            img = cv2_to_pil(img)
            img = (self.tfms(img))
            frames.append(img)
        frames = torch.from_numpy(np.stack(frames))
        return torch.FloatTensor(np.array(frames)).permute(1,0,2,3)

train_transform = Compose([
                 ToTensor(), 
                 Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989])])

# %%
crash_ego_train_dataset = CustomDataset1(crash_ego_train_set['video_path'].values, crash_ego_train_set['label'].values,tfms = train_transform)
crash_ego_train_loader = DataLoader(crash_ego_train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)
crash_ego_val_dataset = CustomDataset1(crash_ego_val_set['video_path'].values, crash_ego_val_set['label'].values,tfms = train_transform)
crash_ego_val_loader = DataLoader(crash_ego_val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

timing_train_dataset = CustomDataset2(timing_train_set['video_path'].values, timing_train_set['label'].values,tfms = train_transform)
timing_train_loader = DataLoader(timing_train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)
timing_val_dataset = CustomDataset2(timing_val_set['video_path'].values, timing_val_set['label'].values,tfms = train_transform)
timing_val_loader = DataLoader(timing_val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

weather_train_dataset = CustomDataset2(weather_train_set['video_path'].values, weather_train_set['label'].values,tfms = train_transform)
weather_train_loader = DataLoader(weather_train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)
weather_val_dataset = CustomDataset2(weather_val_set['video_path'].values, weather_val_set['label'].values,tfms = train_transform)
weather_val_loader = DataLoader(weather_val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
# test data (img size: 128)
test_dataset = CustomDataset1(test['video_path'].values, None, tfms = train_transform)
test_loader = DataLoader(test_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=4)
# test data (img size: 200)
w_test_dataset = CustomDataset2(test['video_path'].values, None, tfms = train_transform)
w_test_loader = DataLoader(w_test_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=4)

# %%
class BaseModel2(nn.Module): # crash+ego_involve
    def __init__(self, num_classes=3):
        super(BaseModel2, self).__init__()
        self.feature_extract = models.video.r3d_18(pretrained=True)
        self.f1 = nn.Linear(400, 256)
        self.f3 = nn.Linear(256, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        batch_size = x.size(0)
        x = self.feature_extract(x)
        x = x.view(batch_size, -1)
        x = F.relu(self.f1(x))
        x = self.dropout(x)
        x = self.f3(x)
        return x

# %%
class BaseModel3(nn.Module): # timing
    def __init__(self, num_classes=2):
        super(BaseModel3, self).__init__()
        self.feature_extract = models.video.r3d_18(pretrained=True)
        self.f1 = nn.Linear(400, 256)
        self.f3 = nn.Linear(256, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        batch_size = x.size(0)
        x = self.feature_extract(x)
        x = x.view(batch_size, -1)
        x = F.relu(self.f1(x))
        x = self.dropout(x)
        x = self.f3(x)
        return x

# %%
class BaseModel4(nn.Module): # weather
    def __init__(self, num_classes=3):
        super(BaseModel4, self).__init__()
        self.feature_extract = models.video.r3d_18(pretrained=True)
        self.f1 = nn.Linear(400, 256)
        self.f3 = nn.Linear(256, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        batch_size = x.size(0)
        x = self.feature_extract(x)
        x = x.view(batch_size, -1)
        x = F.relu(self.f1(x))
        x = self.dropout(x)
        x = self.f3(x)
        return x

# %%
#train

def train(model, optimizer, train_loader, val_loader, scheduler, device, best_val_score): # epoch: 1
    model.to(device)
    criterion = nn.CrossEntropyLoss().to(device)
    Iter = round(len(crash_ego_train_set)/4)
    best_val_score = best_val_score
    best_model = model
    
    for epoch in range(1, 2):
        model.train() 
        train_loss = []
        bat = 1
        for videos, labels in tqdm(iter(train_loader)): 
            
            videos = videos.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            output = model(videos)
            loss = criterion(output, labels)

            loss.backward()
            optimizer.step()
            bat += 1
            train_loss.append(loss.item())
            print(f"batch {bat}/{Iter}", end='\r')
            
        _val_loss, _val_score, _f1_ = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val F1 : {_val_score} [{_f1_:.5f}]')
        
        if scheduler is not None:
            scheduler.step(_f1_)

        if best_val_score < _f1_:
            best_val_score = _f1_
            best_model = model
    return best_model, best_val_score

# %%
def train2(model, optimizer, train_loader, val_loader, scheduler,  device, best_val_score): # epoch: 2
    criterion = nn.CrossEntropyLoss().to(device)
    Iter = round(len(crash_ego_train_set)/4)
    best_val_score = best_val_score
    best_model = model
    
    for epoch in range(1,3):
        model.train()
        train_loss = []
        bat = 1
        for videos, labels in tqdm(iter(train_loader)): 
            
            videos = videos.to(device)
            labels = labels.to(device) 
            optimizer.zero_grad()
            output = model(videos)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            bat += 1
            train_loss.append(loss.item())
            print(f"batch {bat}/{Iter}", end='\r')
            
        _val_loss, _val_score, _f1_ = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val F1 : {_val_score} [{_f1_:.5f}]')
        
        if scheduler is not None:
            scheduler.step(_f1_)

        if best_val_score < _f1_:
            best_val_score = _f1_
            best_model = model
    return best_model, best_val_score

# %%
def train3(model, optimizer, train_loader, val_loader, scheduler, device, best_val_score): # epoch: 3
    model.to(device)
    criterion = nn.CrossEntropyLoss().to(device)
    Iter = round(len(crash_ego_train_set)/4)
    best_val_score = best_val_score
    best_model = model
    
    for epoch in range(1, 4):
        model.train()
        train_loss = []
        bat = 1
        for videos, labels in tqdm(iter(train_loader)): 
            
            videos = videos.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            output = model(videos)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            bat += 1
            train_loss.append(loss.item())
            print(f"batch {bat}/{Iter}", end='\r')
    
        _val_loss, _val_score, _f1_= validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val F1 : {_val_score} [{_f1_:.5f}]')
        
        if scheduler is not None:
            scheduler.step(_f1_)

        if best_val_score < _f1_:
            best_val_score = _f1_
            best_model = model
    return best_model, best_val_score

# %%
def train5(model, optimizer, train_loader, val_loader, scheduler, device, best_val_score): # epoch: 5
    model.to(device)
    criterion = nn.CrossEntropyLoss().to(device)
    Iter = round(len(crash_ego_train_set)/4)
    best_val_score = best_val_score
    best_model = model
    
    for epoch in range(1, 6):
        model.train()
        train_loss = []
        bat = 1
        for videos, labels in tqdm(iter(train_loader)): 
            
            videos = videos.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            output = model(videos)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            bat += 1
            train_loss.append(loss.item())
            print(f"batch {bat}/{Iter}", end='\r')
    
        _val_loss, _val_score, _f1_= validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val F1 : {_val_score} [{_f1_:.5f}]')
        
        if scheduler is not None:
            scheduler.step(_f1_)

        if best_val_score < _f1_:
            best_val_score = _f1_
            best_model = model
    return best_model, best_val_score

# %%
def validation(model, criterion, val_loader, device):
    model.eval()
    val_loss = []
    preds, trues = [], []
    bat = 1
    Iter = round(len(crash_ego_val_set)/4)
    with torch.no_grad():
        for videos, labels in tqdm(iter(val_loader)):
            videos = videos.to(device)
            labels = labels.to(device)

            logit = model(videos)
            
            loss = criterion(logit, labels)
            
            val_loss.append(loss.item())
            _val_loss = np.mean(val_loss)
            bat += 1
            
            preds += logit.argmax(1).detach().cpu().numpy().tolist()
            trues += labels.detach().cpu().numpy().tolist()
            if bat%10 == 0:
                print(f"batch {bat}/{Iter} Val Loss: {_val_loss}", end='\r')
            
        _val_loss = np.mean(val_loss)
    
    _val_score = f1_score(trues, preds, average=None)
    _f1_ = f1_score(trues, preds, average='macro')
    return _val_loss, _val_score, _f1_

# %%
def inference(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad():
        for videos in tqdm(iter(test_loader)):
            videos = videos.to(device)
        
            logit = model(videos)
            
            preds += logit.argmax(1).detach().cpu().numpy().tolist()
    return preds

# %%
ml = BaseModel4()
ml.eval()
optimizer = torch.optim.Adam(params = ml.parameters(), lr = 1e-4, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, 
                                                       patience=2,threshold_mode='abs',min_lr=1e-8, verbose=True)
infer_ml, best_val_score = train(ml, optimizer, weather_train_loader, weather_val_loader, scheduler, device, 0)
# Out:
# Downloading: "https://download.pytorch.org/models/r3d_18-b3b3357e.pth" to /root/.cache/torch/hub/checkpoints/r3d_18-b3b3357e.pth
# 100%|██████████| 127M/127M [00:02<00:00, 48.9MB/s]
#   0%|          | 0/178 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-792b43b36e8c> in <cell line: 6>()
#       4 scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5,
#       5                                                        patience=2,threshold_mode='abs',min_lr=1e-8, verbose=True)
# ----> 6 infer_ml, best_val_score = train(ml, optimizer, weather_train_loader, weather_val_loader, scheduler, device, 0)
#
# <ipython-input-30-ebb03ff93c5a> in train(model, optimizer, train_loader, val_loader, scheduler, device, best_val_score)
#      20             loss = criterion(output, labels)
#      21
# ---> 22             loss.backward()
#      23             optimizer.step()
#      24             bat += 1
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.Adam(params = infer_ml.parameters(), lr = 5e-5, weight_decay=1e-5)
infer_ml, best_val_score = train(infer_ml, optimizer, weather_train_loader, weather_val_loader, None, device, best_val_score)

# %%
optimizer = torch.optim.Adam(params = infer_ml.parameters(), lr = 1e-5, weight_decay=1e-5)
infer_ml, best_val_score = train(infer_ml, optimizer, weather_train_loader, weather_val_loader, None, device, best_val_score)

# %%
optimizer = torch.optim.Adam(params = infer_ml.parameters(), lr = 1e-6, weight_decay=1e-5)
infer_ml, best_val_score = train(infer_ml, optimizer, weather_train_loader, weather_val_loader, None, device, best_val_score)

# %%
weather_preds = inference(infer_ml, test_loader, device)

# %%
weather_result = pd.read_csv('./data/sample_submission.csv')
weather_result['label'] = weather_preds
weather_result.to_csv('./drive/MyDrive/result/weather1.csv')
